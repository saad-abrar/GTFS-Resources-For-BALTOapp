# %%
import pandas as pd

stops = pd.read_csv("../mdotmta_gtfs_metro/stops.txt")
stops
# Out:
#     stop_id  stop_code                              stop_name  stop_desc  \
# 0      4819       4819          REISTERSTOWN PLAZA (METRO) sb        NaN
# 1      5584       5584         WEST COLD SPRING STATION METRO        NaN
# 2      5585       5585         WEST COLD SPRING STATION METRO        NaN
# 3      7500       7500           OWINGS MILLS STATION (METRO)        NaN
# 4      7503       7503           MONDAWMIN STATION (METRO) sb        NaN
# 5      7504       7504          PENN NORTH STATION (METRO) sb        NaN
# 6      7505       7505               UPTON STATION (METRO) sb        NaN
# 7      7506       7506                STATE CENTER (METRO) sb        NaN
# 8      7507       7507            LEXINGTON MARKET (METRO) sb        NaN
# 9      7508       7508              CHARLES CENTER (METRO) sb        NaN
# 10     7509       7509          SHOT TOWER STATION (METRO) sb        NaN
# 11     7510       7510          JOHNS HOPKINS STATION (METRO)        NaN
# ...

# %%
stop_times = pd.read_csv("../mdotmta_gtfs_metro/stop_times.txt")
stop_times
# Out:
#        trip_id arrival_time departure_time  stop_id  stop_sequence  \
# 0      2553887     05:00:00       05:00:00     7500              1
# 1      2553887     05:04:00       05:04:00    10906              2
# 2      2553887     05:07:00       05:07:00    11422              3
# 3      2553887     05:09:00       05:09:00     4819              4
# 4      2553887     05:11:00       05:11:00    10419              5
# ...        ...          ...            ...      ...            ...
# 14781  2746887     24:02:00       24:02:00    10420             10
# 14782  2746887     24:04:00       24:04:00     7519             11
# 14783  2746887     24:06:00       24:06:00     7520             12
# 14784  2746887     24:09:00       24:09:00     7522             13
# 14785  2746887     24:14:00       24:14:00     7500             14
#
#        stop_headsign  pickup_type  drop_off_type  shape_dist_traveled
# 0                NaN          NaN            NaN                  NaN
# ...

# %%
# Finding unique trip ids
unique_trip_ids = stop_times["trip_id"].unique()
len(unique_trip_ids)
# Out:
# 1102

# %%
from datetime import datetime
#hmm = pd.strftime("%h:%m:%s")
#stop_times["arrival_time"] = pd.to_datetime(stop_times["arrival_time"], infer_datetime_format=True)
#stop_times["arrival_time"] = stop_times["arrival_time"].strftime("%H:%M:%S")
#stop_times["arrival_time"]
stop_times["arrival_time"]=pd.to_timedelta(stop_times["arrival_time"])
stop_times["departure_time"] = pd.to_timedelta(stop_times["departure_time"])

# %%
import numpy as np
# calculating the interstop timings   
timing_dict_array=[]
stop_times.groupby("trip_id")
stop_times["next_stop_time"] = np.nan
#stop_times

#stop_times["hell"] = stop_times[]

#for trip in unique_trip_ids:
#    timing_dict={}
#    stop_times.loc[stop_times["trip_id"]==2482827][["arrival_time","departure_time","stop_sequence"]]
#new = stop_times.loc[stop_times["trip_id"]==2482827]
#new["next_stop_time"] = np.nan

for i in range(0,len(stop_times)):
    if(i==len(stop_times)-1):
        stop_times.loc[i,"next_stop_time"] = -1
        break
    if stop_times.loc[i+1,"stop_sequence"] == 1:
        stop_times.loc[i,"next_stop_time"] = -1
        continue
    stop_times.loc[i,'next_stop_time'] = (stop_times.loc[i+1, "arrival_time"] - stop_times.loc[i,"arrival_time"]).total_seconds()/60 

    
#for trip in unique_trip_ids:
#    timing_dict = {}
#

# %%
stop_times
# Out:
#        trip_id    arrival_time  departure_time  stop_id  stop_sequence  \
# 0      2553887 0 days 05:00:00 0 days 05:00:00     7500              1
# 1      2553887 0 days 05:04:00 0 days 05:04:00    10906              2
# 2      2553887 0 days 05:07:00 0 days 05:07:00    11422              3
# 3      2553887 0 days 05:09:00 0 days 05:09:00     4819              4
# 4      2553887 0 days 05:11:00 0 days 05:11:00    10419              5
# ...        ...             ...             ...      ...            ...
# 14781  2746887 1 days 00:02:00 1 days 00:02:00    10420             10
# 14782  2746887 1 days 00:04:00 1 days 00:04:00     7519             11
# 14783  2746887 1 days 00:06:00 1 days 00:06:00     7520             12
# 14784  2746887 1 days 00:09:00 1 days 00:09:00     7522             13
# 14785  2746887 1 days 00:14:00 1 days 00:14:00     7500             14
#
#        stop_headsign  pickup_type  drop_off_type  shape_dist_traveled  \
# ...

# %%
#stop_times.loc[stop_times["trip_id"]==2482827]
# Out:
# Empty DataFrame
# Columns: [trip_id, arrival_time, departure_time, stop_id, stop_sequence, stop_headsign, pickup_type, drop_off_type, shape_dist_traveled, timepoint, next_stop_time]
# Index: []

# %%
stop_times.to_csv("../mdotmta_gtfs_metro/stop_times_modified.csv",sep=',',index = False)
